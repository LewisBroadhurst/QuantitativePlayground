# %%
import os
import sys
sys.path.append("../../")

from coinbase.rest import RESTClient
# from coinbase.websocket import WSClient
from json import dumps
from dotenv import dotenv_values, load_dotenv

load_dotenv()
secrets = dotenv_values(".env")

api_key = os.getenv('COINBASE_API_KEY_TRADING_040224')
api_secret = os.getenv('COINBASE_API_SECRET_TRADING_040224')
client = RESTClient(api_key=api_key, api_secret=api_secret)

# %%
# Gets accounts... i.e. NEAR, Polkadot, etc.
accounts = client.get_accounts()
# print(dumps(accounts, indent=2))

# %%
# Get Best Bid/Ask
bid_ask = client.get_best_bid_ask()
pricebooks = bid_ask['pricebooks']

desired_instruments = ['BTC-USD', 'ETH-USD', 'SOL-USD']

# for pricebook in pricebooks:
#     if pricebook['product_id'] in desired_instruments:
        # print(pricebook)

# %%
# Get Product Candles
x = client.get_candles('BTC-USD', 1682531200, 1704067200, 'ONE_DAY')
# print(x['candles'])

# %%
import pickle
import pandas as pd

x = pd.read_pickle("../scripts/COINBASE_CANDLESTICKS__test")
print(x)
# Out:
# E:\workspace\CoinbaseTradingviewFinanceFun\server\coinbase_backtesting_bot\notebooks
# [{'start': '1696032000', 'low': '26884.86', 'high': '27097.25', 'open': '26905.57', 'close': '26961', 'volume': '4413.30948101'}, {'start': '1695945600', 'low': '26661.71', 'high': '27238.9', 'open': '27027.44', 'close': '26907', 'volume': '12712.27177691'}, {'start': '1695859200', 'low': '26321.37', 'high': '27313.86', 'open': '26357.56', 'close': '27027.14', 'volume': '18975.87763693'}, {'start': '1695772800', 'low': '26088.37', 'high': '26830', 'open': '26208.43', 'close': '26357.62', 'volume': '14123.89690964'}, {'start': '1695686400', 'low': '26080', 'high': '26397.59', 'open': '26296.07', 'close': '26208.44', 'volume': '7016.42122845'}, {'start': '1695600000', 'low': '25983.78', 'high': '26444.95', 'open': '26248.17', 'close': '26296.08', 'volume': '10762.98401397'}, {'start': '1695513600', 'low': '26118.86', 'high': '26731.1', 'open': '26579.59', 'close': '26250.24', 'volume': '4587.80529114'}, {'start': '1695427200', 'low': '26513', 'high': '26638.58', 'open': '26578.4', 'close': '26579.6', 'volume': '2597.25705711'}, {'start': '1695340800', 'low': '26467.94', 'high': '26742.86', 'open': '26564.54', 'close': '26578.4', 'volume': '8563.0523313'}, {'start': '1695254400', 'low': '26359.7', 'high': '27163.48', 'open': '27122.65', 'close': '26564.54', 'volume': '11801.98943642'}, {'start': '1695168000', 'low': '26798.98', 'high': '27393.78', 'open': '27216.52', 'close': '27123.94', 'volume': '11590.24027633