# %%
import os
import sys
sys.path.append("../../")

from coinbase.rest import RESTClient
# from coinbase.websocket import WSClient
from json import dumps
from dotenv import dotenv_values, load_dotenv

load_dotenv()
secrets = dotenv_values(".env")

api_key = os.getenv('COINBASE_API_KEY_TRADING_040224')
api_secret = os.getenv('COINBASE_API_SECRET_TRADING_040224')
client = RESTClient(api_key=api_key, api_secret=api_secret)

# %%
# Gets accounts... i.e. NEAR, Polkadot, etc.
accounts = client.get_accounts()
# print(dumps(accounts, indent=2))

# %%
# Get Best Bid/Ask
bid_ask = client.get_best_bid_ask()
pricebooks = bid_ask['pricebooks']

desired_instruments = ['BTC-USD', 'ETH-USD', 'SOL-USD']

for pricebook in pricebooks:
    if pricebook['product_id'] in desired_instruments:
        print(pricebook)
# Out:
# {'product_id': 'ETH-USD', 'bids': [{'price': '2301.09', 'size': '0.75'}], 'asks': [{'price': '2301.34', 'size': '0.73551721'}], 'time': '2024-02-04T16:53:14.796015Z'}
# {'product_id': 'BTC-USD', 'bids': [{'price': '42877.35', 'size': '0.02'}], 'asks': [{'price': '42879.25', 'size': '0.02800184'}], 'time': '2024-02-04T16:53:14.329947Z'}
# {'product_id': 'SOL-USD', 'bids': [{'price': '97.22', 'size': '0.027'}], 'asks': [{'price': '97.23', 'size': '63.593'}], 'time': '2024-02-04T16:53:14.625856Z'}

# %%
# Get Product Candles
x = client.get_candles('BTC-USD', 1682531200, 1704067200, 'ONE_DAY')
print(x['candles'])
# Out:
# [{'start': '1704067200', 'low': '42175.65', 'high': '44240.8', 'open': '42288.58', 'close': '44220.78', 'volume': '7977.72851143'}, {'start': '1703980800', 'low': '41964.68', 'high': '42850', 'open': '42139.32', 'close': '42288.06', 'volume': '11397.57303743'}, {'start': '1703894400', 'low': '41518.19', 'high': '42593.73', 'open': '42064.22', 'close': '42141.03', 'volume': '11609.82377015'}, {'start': '1703808000', 'low': '41300', 'high': '43137.1', 'open': '42581.23', 'close': '42063.45', 'volume': '16756.43323881'}, {'start': '1703721600', 'low': '42265.08', 'high': '43830.34', 'open': '43469.06', 'close': '42581.23', 'volume': '13583.91599843'}, {'start': '1703635200', 'low': '42111.47', 'high': '43709.98', 'open': '42521.21', 'close': '43474.4', 'volume': '12917.48404475'}, {'start': '1703548800', 'low': '41600.67', 'high': '43605', 'open': '43589.67', 'close': '42515.53', 'volume': '13030.02545286'}, {'start': '1703462400', 'low': '42755.35', 'high': '43818.29', 'open': '43025.02', 'close': '43589.67', 'volume': '4799.73104807'}, {'start': '1703376000', 'low': '42614.17', 'high': '43985.67', 'open': '43728.36', 'close': '43025.03', 'volume': '4947.00165569'}, {'start': '1703289600', 'low': '43333.35', 'high': '44033